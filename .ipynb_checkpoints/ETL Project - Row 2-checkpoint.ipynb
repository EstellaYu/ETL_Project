# %% [markdown]
# # ETL Project

# %% [markdown]
# # 1. Dependencies

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

import pymongo

# %%
# get chromedriver location
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %% [markdown]
# # 2. EXTRACT

# %% [markdown]
# ## 2.1 Visa Requirements for US Citizens -- web scraping `.html`

# %%
# launch chromedriver -- get an empty page
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://en.wikipedia.org/wiki/Visa_requirements_for_United_States_citizens"
browser.visit(url)

# %%
tables = pd.read_html(browser.html)
visa_df = tables[0]
browser.quit()

# %%
# drop the unnecesary cols
col_to_drop = ['Allowed stay']
visa_df.drop(col_to_drop, axis = 1, inplace = True)

# rename cols
visa_df.rename(columns={'Country':'Country',
                        "Visa requirement":'visa_requirement',
                        "Notes (excluding departure fees)":'notes'},
              inplace = True)
visa_df.head()
# Out:
#        Country         visa_requirement  \
# 0  Afghanistan      Visa required[2][3]
# 1      Albania  Visa not required[5][6]
# 2      Algeria      Visa required[8][9]
# 3      Andorra    Visa not required[10]
# 4       Angola        eVisa[13][14][15]
#
#                                                notes
# 0  Visitors born in Afghanistan do not require a ...
# 1                                                NaN
# 2  Persons may be denied entry if entering with a...
# 3                                                NaN
# 4  Visitors who have been granted an online pre-v...

# %%
# clean up the citation marks
for i in range(len(visa_df)):
    visa_df.iloc[i,1] = visa_df.iloc[i,1].split('[')[0]

# %%
visa_df['visa_requirement'].value_counts()
# Out:
# Visa not required                  107
# Visa required                       30
# Visa on arrival                     19
# eVisa / Visa on arrival             18
# eVisa                               11
# Travel restricted                    1
# Visitor's Permit on arrival          1
# Tourist Card required                1
# Visitor's permit on arrival          1
# Entry Permit on arrival              1
# Electronic Travel Authority          1
# eVisa / Tourist card on arrival      1
# Online Visa                          1
# Name: visa_requirement, dtype: int64

# %%
auto_visa_key_words = ["on arrival", 'eVisa', 'Electronic', 'Online']
restrict_list = ["Tourist Card required", "Travel restricted"]

for i in range(len(visa_df)):
    for word in auto_visa_key_words:
        if word in visa_df['visa_requirement'][i]:
            visa_df['visa_requirement'][i] = "eVisa/Visa on arrival"
            continue
    if visa_df['visa_requirement'][i] in restrict_list:
        visa_df['visa_requirement'][i] = "Travel restricted"

# %%
visa_df['visa_requirement'].value_counts()
# Out:
# Visa not required        107
# eVisa/Visa on arrival     54
# Visa required             30
# Travel restricted          2
# Name: visa_requirement, dtype: int64

# %%
visa_df.set_index('Country',drop=True, inplace=True)
visa_df.head()
# Out:
#                   visa_requirement  \
# Country
# Afghanistan          Visa required
# Albania          Visa not required
# Algeria              Visa required
# Andorra          Visa not required
# Angola       eVisa/Visa on arrival
#
#                                                          notes
# Country
# Afghanistan  Visitors born in Afghanistan do not require a ...
# Albania                                                    NaN
# Algeria      Persons may be denied entry if entering with a...
# Andorra                                                    NaN
# Angola       Visitors who have been granted an online pre-v...

# %% [markdown]
# ## 2.2 GDP by Country -- from `.csv` file

# %%
# The CSV file is in the resources directory
# The source website is https://data.worldbank.org/indicator/ny.gdp.mktp.cd
gdp_filename = "resources/GDP_by_country.csv"
gdp_df = pd.read_csv(gdp_filename)
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
#            2009          2010          2011          2012          2013  \
# 0  2.498883e+09  2.390503e+09  2.549721e+09  2.534637e+09  2.581564e+09
# 1  1.243909e+10  1.585657e+10  1.780428e+10  2.000162e+10  2.056105e+10
# 2  7.030716e+10  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11
# 3  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10  1.277628e+10
# 4  3.660531e+09  3.355695e+09  3.442063e+09  3.164615e+09  3.281585e+09
#
#            2014          2015          2016          2017          2018
# 0  2.649721e+09  2.691620e+09  2.646927e+09  2.700559e+09           NaN
# 1  2.048487e+10  1.990711e+10  1.936264e+10  2.019176e+10  1.936297e+10
# 2  1.457120e+11  1.161940e+11  1.011240e+11  1.221240e+11  1.057510e+11
# 3  1.322825e+10  1.138693e+10  1.186135e+10  1.302506e+10  1.505888e+10
# 4  3.350736e+09  2.811489e+09  2.877312e+09  3.013387e+09  3.236544e+09
#
# [5 rows x 63 columns]

# %%
gdp_df.drop(columns=["Country Code","Indicator Name","Indicator Code"], inplace=True)
gdp_df.head()
# Out:
#   Country Name         1960         1961         1962         1963  \
# 0        Aruba          NaN          NaN          NaN          NaN
# 1  Afghanistan  537777811.1  548888895.6  546666677.8  751111191.1
# 2       Angola          NaN          NaN          NaN          NaN
# 3      Albania          NaN          NaN          NaN          NaN
# 4      Andorra          NaN          NaN          NaN          NaN
#
#           1964          1965          1966          1967          1968  ...  \
# 0          NaN           NaN           NaN           NaN           NaN  ...
# 1  800000044.4  1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09  ...
# 2          NaN           NaN           NaN           NaN           NaN  ...
# 3          NaN           NaN           NaN           NaN           NaN  ...
# 4          NaN           NaN           NaN           NaN           NaN  ...
#
#            2009          2010          2011          2012          2013  \
# 0  2.498883e+09  2.390503e+09  2.549721e+09  2.534637e+09  2.581564e+09
# 1  1.243909e+10  1.585657e+10  1.780428e+10  2.000162e+10  2.056105e+10
# 2  7.030716e+10  8.379950e+10  1.117900e+11  1.280530e+11  1.367100e+11
# 3  1.204421e+10  1.192695e+10  1.289087e+10  1.231978e+10  1.277628e+10
# 4  3.660531e+09  3.355695e+09  3.442063e+09  3.164615e+09  3.281585e+09
#
#            2014          2015          2016          2017          2018
# 0  2.649721e+09  2.691620e+09  2.646927e+09  2.700559e+09           NaN
# 1  2.048487e+10  1.990711e+10  1.936264e+10  2.019176e+10  1.936297e+10
# 2  1.457120e+11  1.161940e+11  1.011240e+11  1.221240e+11  1.057510e+11
# 3  1.322825e+10  1.138693e+10  1.186135e+10  1.302506e+10  1.505888e+10
# 4  3.350736e+09  2.811489e+09  2.877312e+09  3.013387e+09  3.236544e+09
#
# [5 rows x 60 columns]

# %%
years = np.arange(1960,2018)
years_str = [str(yy) for yy in years]
gdp_df.drop(columns=years_str, inplace=True)
gdp_df.dropna(inplace=True)
gdp_df.rename(columns={"Country Name": "Country", "2018":"GDP 2018"}, inplace=True)
gdp_df.set_index("Country", inplace=True)
gdp_df.head()
# Out:
#                  GDP 2018
# Country
# Afghanistan  1.936297e+10
# Angola       1.057510e+11
# Albania      1.505888e+10
# Andorra      3.236544e+09
# Arab World   2.781330e+12

# %% [markdown]
# ## 2.3 Top 100 Tourist Destinations Worldwide -- web scraping Brilliant Maps `.html`

# %%
# URL of page to be scraped
url = "https://brilliantmaps.com/top-100-tourist-destinations/"

# Retrieve page
response = requests.get(url)

# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# Examine the results, then determine element that contains sought info
# print(soup.prettify())

# %%
# Get the Top Destinations table, show the top 20 destinations
destinations = pd.read_html(response.text)
top_destinations=destinations[0]
top_destinations.head(5)
# Out:
#    Rank       City    Country  Tourists (Millions)
# 0     1  Hong Kong  Hong Kong                 23.7
# 1     2  Singapore  Singapore                 21.3
# 2     3    Bangkok   Thailand                 15.8
# 3     4     London         UK                 15.5
# 4     5      Macau      Macau                 13.4

# %%
del top_destinations['Rank']
top_destinations.rename(columns={"City":"city","Tourists (Millions)":"tourists_mm"}, inplace=True)
top_destinations.set_index('Country', inplace = True)
top_destinations.head()
# Out:
#                 city  tourists_mm
# Country
# Hong Kong  Hong Kong         23.7
# Singapore  Singapore         21.3
# Thailand     Bangkok         15.8
# UK            London         15.5
# Macau          Macau         13.4

# %% [raw]
# # Note that some countries have more than one city in the Global Top 100
# # Get a list of all popular cities aggregated by countries
# test = top_destinations.copy().set_index('Rank')
#
# city_list_df = pd.DataFrame({'count': test.groupby(['Country'])['City'].count(),
#                             'city': test.groupby(['Country'])['City'].apply(list),
#                             'tourists (mm)': test.groupby(['Country'])["Tourists (Millions)"].apply(list)})
# city_list_df.head()

# %% [markdown]
# ## 2.4 Favorite dishes by country --  `.json` file

# %%
# This json file comes from someone's github directory
# https://github.com/samayo/country-json/blob/master/src/country-by-national-dish.json

filepath = "resources/country-by-national-dish.json"
yummy_df = pd.read_json(filepath)
yummy_df.rename(columns={"country": "Country"}, inplace = True)
yummy_df.set_index("Country", inplace=True)
yummy_df.head()
# Out:
#                         dish
# Country
# Afghanistan     Kabuli Palaw
# Albania            Tav� kosi
# Algeria            Couscous
# American Samoa          None
# Andorra                 None

# %% [markdown]
# ## 2.5 World Countries and population -- web scraping `.html`

# %%
# launch chromedriver -- get an empty page
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.worldometers.info/geography/how-many-countries-are-there-in-the-world/"
browser.visit(url)

# %%
tables = pd.read_html(browser.html)
population_df = tables[0]

del population_df['#']
population_df.set_index('Country', inplace = True)
population_df.head()
# Out:
#                Population(2019) World Share  Land Area (Km²)
# Country
# China                1420062022      18.4 %          9388211
# India                1368737513      17.7 %          2973190
# United States         329093110       4.3 %          9147420
# Indonesia             269536482       3.5 %          1811570
# Brazil                212392717       2.8 %          8358140

# %%
browser.quit()

# %% [markdown]
# # 3. TRANSFORM

# %% [markdown]
# **3.1 Clean-up country lists**

# %%
# function used to clean up the countries
def clean_up(df, unify_dict, drop_list):
    test = df.reset_index()
    for ct in drop_list:
        test = test[test['Country'] != ct]

    for i in range(len(test)):
        for key in unify_dict:
            if test.iloc[i, 0] in unify_dict[key]:
                test.iloc[i,0] = key
                
    return test

# %%
def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

visa_ct_list = visa_df.index.to_list()
gdp_ct_list = gdp_df.index.to_list()
# city_ct_list = city_list_df.index.to_list()
city_ct_list = top_destinations.index.unique().to_list()
yummy_ct_list = yummy_df.index.to_list()
pop_ct_list = population_df.index.to_list()

lists = [visa_ct_list, gdp_ct_list, city_ct_list, yummy_ct_list, pop_ct_list]

for l in lists:
    print(f'\n{namestr(l, globals())[0]} : {len(l)}')
    print('-----------------------------')
    print(l[:10] +['...'])
# Out:
# visa_ct_list : 193
# -----------------------------
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria', '...']
#
# gdp_ct_list : 231
# -----------------------------
# ['Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia', 'Antigua and Barbuda', 'Australia', '...']
#
# city_ct_list : 53
# -----------------------------
# ['Hong Kong', 'Singapore', 'Thailand', 'UK', 'Macau', 'Malaysia', 'China', 'USA', 'Turkey', 'France', '...']
#
# yummy_ct_list : 243
# -----------------------------
# ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina', '...']
#
# pop_ct_list : 195
# -----------------------------
# ['China', 'India', 'United States', 'Indonesia', 'Brazil', 'Pakistan', 'Nigeria', 'Bangladesh', 'Russia', 'Mexico', '...']

# %% [markdown]
# **1) Visa Country list**

# %%
# special: United States -- since Visa_df applies to US citizens
# Unify the two lists

unify_dict = {"Democratic Republic of the Congo" : ["Democratic Republic of the Congo", "DR Congo"],
 "Czech Republic": ["Czech Republic", "Czechia"],
 "Republic of the Congo" : ["Republic of the Congo", "Congo"],
 "Saint Kitts & Nevis": ["Saint Kitts and Nevis", "Saint Kitts & Nevis"],
 "St. Vincent & Grenadines" : ["St. Vincent & Grenadines","Saint Vincent and the Grenadines"],
 "Sao Tome & Principe": ["Sao Tome & Principe","São Tomé and Príncipe"],
 "Eswatini": ["Eswatini","Swaziland"],
 "Cape Verde": ["Cape Verde","Cabo Verde"]
}

drop_list = ["State of Palestine", "Holy See"]

# %%
visa_df = clean_up(visa_df, unify_dict, drop_list)
population_df = clean_up(population_df, unify_dict, drop_list)

# %%
df2 = pd.DataFrame([["Vatican City", 1000, '0 %', 0.44]], columns = list(population_df.columns))
population_df = population_df.append(df2, ignore_index=True)
population_df.head()
# Out:
#          Country  Population(2019) World Share  Land Area (Km²)
# 0          China        1420062022      18.4 %        9388211.0
# 1          India        1368737513      17.7 %        2973190.0
# 2  United States         329093110       4.3 %        9147420.0
# 3      Indonesia         269536482       3.5 %        1811570.0
# 4         Brazil         212392717       2.8 %        8358140.0

# %%
# update country name list 
population_df.set_index('Country', inplace = True)
visa_df.set_index('Country', inplace = True)

visa_ct_list = visa_df.index.to_list()
pop_ct_list = population_df.index.to_list()

lists = [visa_ct_list, gdp_ct_list, city_ct_list, yummy_ct_list, pop_ct_list]

# %%
# countries in Population_df but not Visa_df
test_A = [x for x in pop_ct_list if x not in list(set(pop_ct_list) & set(visa_ct_list))]
# print(sorted(test_A))
# countries in Visa_df but not Population_df
test_B = [x for x in visa_ct_list if x not in list(set(pop_ct_list) & set(visa_ct_list))]
print(sorted(test_B))
# Out:
# []

# %% [markdown]
# **2) GDP Country list**

# %%
# special: United States -- since Visa_df applies to US citizens
# Unify the two lists

unify_dict = {"Democratic Republic of the Congo" : ["Democratic Republic of the Congo", 
                                                    "DR Congo", "Congo, Dem. Rep.",
                                                    "The Democratic Republic of Congo"],
 "Czech Republic": ["Czech Republic", "Czechia"],
 "Republic of the Congo" : ["Republic of the Congo", "Congo", "Congo, Rep."],
 "Saint Kitts & Nevis": ["Saint Kitts and Nevis", "Saint Kitts & Nevis", "St. Kitts and Nevis"],
 "St. Vincent & Grenadines" : ["St. Vincent & Grenadines",
                               "Saint Vincent and the Grenadines", 
                               "St. Vincent and the Grenadines"],
 "Sao Tome & Principe": ["Sao Tome & Principe","São Tomé and Príncipe", "Sao Tome and Principe"],
 "Eswatini": ["Eswatini","Swaziland"],
 "Côte d'Ivoire" : ["Côte d'Ivoire", "Cote d'Ivoire"],
 "Cape Verde": ["Cape Verde","Cabo Verde"],
 "Egypt" : ["Egypt, Arab Rep.","Egypt"],
 "Gambia" : ["Gambia, The", "Gambia"],
 "South Korea": ["Korea, Rep.","South Korea"],
 "Kyrgyzstan": ["Kyrgyz Republic", "Kyrgyzstan"],
 "Laos" : ["Lao PDR", "Laos"],
 "Micronesia" : ["Micronesia, Fed. Sts.", "Micronesia"],
 "Russia" : ["Russian Federation", "Russia"],
 "Slovakia" : ["Slovak Republic", "Slovakia"],
 "Saint Lucia" : ["St. Lucia", "Saint Lucia"],
 "Yemen" : ["Yemen, Rep.", "Yemen"],
 "Brunei" : ["Brunei Darussalam", "Brunei"]
}

drop_list = ["State of Palestine", "Holy See", 
             "Arab World","Caribbean small states","Central Europe and the Baltics","Early-demographic dividend",
             "East Asia & Pacific", "East Asia & Pacific (IDA & IBRD countries)",
             "East Asia & Pacific (excluding high income)","Euro area", "Europe & Central Asia",
             'Europe & Central Asia (IDA & IBRD countries)','Europe & Central Asia (excluding high income)',
             'European Union','Fragile and conflict affected situations',
             'Heavily indebted poor countries (HIPC)','High income','Hong Kong SAR, China','IBRD only',
             'IDA & IBRD total','IDA blend','IDA only', 'IDA total','Kosovo',
             'Late-demographic dividend', 'Latin America & Caribbean',
             'Latin America & Caribbean (excluding high income)',
             'Latin America & the Caribbean (IDA & IBRD countries)','Least developed countries: UN classification',
             'Low & middle income','Low income','Lower middle income','Macao SAR, China',
             'Middle East & North Africa','Middle income', 'North America','OECD members','Other small states',
             'Pacific island small states','Post-demographic dividend','Pre-demographic dividend','Puerto Rico',
             'Small states','South Asia', 'South Asia (IDA & IBRD)','Sub-Saharan Africa',
             'Sub-Saharan Africa (IDA & IBRD countries)','Sub-Saharan Africa (excluding high income)',
             'Turks and Caicos Islands','West Bank and Gaza', 'World', 'Upper middle income'
            ]

# %%
gdp_df = clean_up(gdp_df, unify_dict, drop_list)
population_df = clean_up(population_df, unify_dict, drop_list)

# %%
# update country name list 
population_df.set_index('Country', inplace = True)
gdp_df.set_index('Country', inplace = True)

gdp_ct_list = gdp_df.index.to_list()
pop_ct_list = population_df.index.to_list()
lists = [visa_ct_list, gdp_ct_list, city_ct_list, yummy_ct_list, pop_ct_list]

# %%
# countries in Population_df but not Visa_df
test_A = [x for x in pop_ct_list if x not in list(set(pop_ct_list) & set(gdp_ct_list))]
# print(sorted(test_A))
# countries in Visa_df but not Population_df
test_B = [x for x in gdp_ct_list if x not in list(set(pop_ct_list) & set(gdp_ct_list))]
sorted(test_B)
# Out:
# []

# %% [markdown]
# **3) yummy Country list**

# %%
yummy_dict = {
    "United States": ["American Samoa", "Guam", "Micronesia, Federated States of","Northern Mariana Islands",
                      "Puerto Rico","United States Minor Outlying Islands","Virgin Islands, U.S.",
                      "USA", "United States"],
    "United Kingdom": ["Anguilla", "Bermuda", "British Indian Ocean Territory","Cayman Islands","England",
                       "Falkland Islands","Gibraltar","Montserrat","Northern Ireland","Pitcairn",
                       "Saint Helena","Scotland","South Georgia and the South Sandwich Islands",
                       "Turks and Caicos Islands","Virgin Islands, British","Wales","UK","United Kingdom"],
    "Netherlands" : ["Aruba","Netherlands Antilles", "Netherlands"],
    "Norway": ["Bouvet Island", "Svalbard and Jan Mayen","Norway"],
    "Australia": ["Christmas Island","Cocos (Keeling) Islands","Heard Island and McDonald Islands", "Australia"],
    "New Zealand": ["Cook Islands","Niue","Norfolk Island","Tokelau","New Zealand"],
    "Timor-Leste": ["East Timor","Timor-Leste"],
    "Denmark": ["Faroe Islands", "Greenland", "Denmark"],
    "Fiji": ["Fiji Islands","Fiji"],
    "France": ["French Guiana", "French Polynesia","French Southern territories", "Guadeloupe", "Martinique", 
               "Mayotte", "New Caledonia","Reunion","Saint Pierre and Miquelon","Wallis and Futuna","France"],
    "China": ["Hong Kong","Macao","Macau","Taiwan", "China"],
    "Côte d'Ivoire": ["Ivory Coast","Côte d'Ivoire"],
    "Libya": ["Libyan Arab Jamahiriya","Libya"],
    "Russian": ["Russian Federation","Russian"],
    "Sri Lanka": ["Sri Lanka","SriLanka"],
    "United Arab Emirates": ["UAE", "United Arab Emirates"]
}

yummy_drop_list = ["Holy See (Vatican City State)","Palestine","Yugoslavia","Western Sahara","Antarctica"]

# %%
unify_dict.update(yummy_dict)
yummy_df = clean_up(yummy_df, unify_dict, drop_list+yummy_drop_list)
population_df = clean_up(population_df, unify_dict, drop_list+yummy_drop_list)

# %%
# update country name list 
population_df.set_index('Country', inplace = True)
yummy_df.set_index('Country', inplace = True)

yummy_ct_list = yummy_df.index.to_list()
pop_ct_list = population_df.index.to_list()
lists = [visa_ct_list, gdp_ct_list, city_ct_list, yummy_ct_list, pop_ct_list]

# %%
# countries in Population_df but not Visa_df
test_A = [x for x in pop_ct_list if x not in list(set(pop_ct_list) & set(yummy_ct_list))]
# print(sorted(test_A))
# countries in Yummy_df but not Population_df
test_B = [x for x in yummy_ct_list if x not in list(set(pop_ct_list) & set(yummy_ct_list))]
print(sorted(test_B))
# Out:
# []

# %% [markdown]
# **4) 100 Travel desitination Country list**

# %%
top_destinations = clean_up(top_destinations, unify_dict, drop_list+yummy_drop_list)
population_df = clean_up(population_df, unify_dict, drop_list+yummy_drop_list)

# %%
top_destinations.set_index('Country', inplace = True)
population_df.set_index('Country', inplace = True)

city_ct_list = top_destinations.index.to_list()
pop_ct_list = population_df.index.to_list()
lists = [visa_ct_list, gdp_ct_list, city_ct_list, yummy_ct_list, pop_ct_list]

# %%
# countries in Population_df but not Visa_df
test_A = [x for x in pop_ct_list if x not in list(set(pop_ct_list) & set(city_ct_list))]
# print(sorted(test_A))
# countries in Visa_df but not Population_df
test_B = [x for x in city_ct_list if x not in list(set(pop_ct_list) & set(city_ct_list))]
print(sorted(test_B))
# Out:
# []

# %% [markdown]
# # 4. LOAD

# %%
visa_df.to_csv("Output/visa_requirement_us_citizen.csv")
visa_df.head()
# Out:
#                   visa_requirement  \
# Country
# Afghanistan          Visa required
# Albania          Visa not required
# Algeria              Visa required
# Andorra          Visa not required
# Angola       eVisa/Visa on arrival
#
#                                                          notes
# Country
# Afghanistan  Visitors born in Afghanistan do not require a ...
# Albania                                                    NaN
# Algeria      Persons may be denied entry if entering with a...
# Andorra                                                    NaN
# Angola       Visitors who have been granted an online pre-v...

# %%
gdp_df.rename(columns={"GDP 2018": "gdp_2018"}, inplace=True)
gdp_df.to_csv("Output/GDP_2018.csv")
gdp_df.head()
# Out:
#                           gdp_2018
# Country
# Afghanistan           1.936297e+10
# Angola                1.057510e+11
# Albania               1.505888e+10
# Andorra               3.236544e+09
# United Arab Emirates  4.141790e+11

# %%
top_destinations.to_csv("Output/top_100_desination.csv")
top_destinations.head()
# Out:
#                    cities  tourists_mm
# Country
# China           Hong Kong         23.7
# Singapore       Singapore         21.3
# Thailand          Bangkok         15.8
# United Kingdom     London         15.5
# China               Macau         13.4

# %%
yummy_df.to_csv("Output/yummy.csv")
yummy_df.head()
# Out:
#                        dish
# Country
# Afghanistan    Kabuli Palaw
# Albania           Tav� kosi
# Algeria           Couscous
# United States          None
# Andorra                None

# %%
population_df.rename(columns={"Population(2019)": "population",
                       "World Share":"world_share",
                       "Land Area (Km²)": "land_area"
                      }, inplace=True)
population_df.to_csv("Output/world_population.csv")
population_df.head()
# Out:
#                population world_share  land_area
# Country
# China          1420062022      18.4 %  9388211.0
# India          1368737513      17.7 %  2973190.0
# United States   329093110       4.3 %  9147420.0
# Indonesia       269536482       3.5 %  1811570.0
# Brazil          212392717       2.8 %  8358140.0

# %% [markdown]
# #### 4.1 SQLAlchemy DataBase

# %%
# create table 
from sqlalchemy import Column, Integer, String, Float, BigInteger
from sqlalchemy.orm import Session

# %%
database_path = "resources/country_db"
engine = create_engine(f"sqlite:///{database_path}")

# %%
conn = engine.connect()
Base = declarative_base()
session = Session(bind = engine)

# %%
class Visa(Base):
    #Tell SQLAlchemy what the table name is and if there's any table-specific arguments it should know about
    __tablename__ = 'Visa'
    __table_args__ = {'sqlite_autoincrement': True}
    #tell SQLAlchemy the name of column and its attributes:
    id = Column(Integer, primary_key=True) 
    country = Column(String)
    visa_requirement = Column(String)
    notes = Column(String)

# %%
class GDP(Base):
    #Tell SQLAlchemy what the table name is and if there's any table-specific arguments it should know about
    __tablename__ = 'GDP'
    __table_args__ = {'sqlite_autoincrement': True}
    #tell SQLAlchemy the name of column and its attributes:
    id = Column(Integer, primary_key=True) 
    country = Column(String)
    gdp_2018 = Column(BigInteger)

# %%
class Population(Base):
    #Tell SQLAlchemy what the table name is and if there's any table-specific arguments it should know about
    __tablename__ = 'Population'
    __table_args__ = {'sqlite_autoincrement': True}
    #tell SQLAlchemy the name of column and its attributes:
    id = Column(Integer) 
    country = Column(String, primary_key=True)
    population = Column(BigInteger)
    world_share  = Column(String)
    land_area = Column(Integer)

# %%
class Yummy(Base):
    #Tell SQLAlchemy what the table name is and if there's any table-specific arguments it should know about
    __tablename__ = 'Yummy'
    __table_args__ = {'sqlite_autoincrement': True}
    #tell SQLAlchemy the name of column and its attributes:
    id = Column(Integer) 
    country = Column(String, primary_key=True)
    dish = Column(String)

# %%
class City_list(Base):
    #Tell SQLAlchemy what the table name is and if there's any table-specific arguments it should know about
    __tablename__ = 'City_list'
    __table_args__ = {'sqlite_autoincrement': True}
    #tell SQLAlchemy the name of column and its attributes:
    id = Column(Integer) 
    country = Column(String, primary_key=True)
    city_count = Column(String)
    cities = Column(String)
    tourists_mm = Column(String)

# %%
visa = pd.read_csv("Output/visa_requirement_us_citizen.csv")
visa.to_sql(con=engine, index_label='id', name=Visa.__tablename__, if_exists='replace')

# %%
gdp = pd.read_csv("Output/GDP_2018.csv")
gdp.to_sql(con=engine, index_label='id', name=GDP.__tablename__, if_exists='replace')

# %%
population = pd.read_csv("Output/world_population.csv")
population.to_sql(con=engine, index_label='id', name=Population.__tablename__, if_exists='replace')

# %%
yummy = pd.read_csv("Output/yummy.csv")
yummy.to_sql(con=engine, index_label='id', name=Yummy.__tablename__, if_exists='replace')

# %%
city_list = pd.read_csv("Output/top_100_desination.csv")
city_list.to_sql(con=engine, index_label='id', name=City_list.__tablename__, if_exists='replace')

# %% [markdown]
# # 5. QUERY TIME!

# %%
rows = session.query(Visa.country, Visa.visa_requirement, GDP.gdp_2018).filter(Visa.country == GDP.country)

# %%
for record in rows:
    print(record)
# Out:
# ('Afghanistan', 'Visa required', 19362969582.0)
# ('Albania', 'Visa not required', 15058879129.0)
# ('Algeria', 'Visa required', 180689000000.0)
# ('Andorra', 'Visa not required', 3236543909.0)
# ('Angola', 'eVisa/Visa on arrival', 105751000000.0)
# ('Antigua and Barbuda', 'Visa not required', 1623804016.0)
# ('Argentina', 'Visa not required', 518475000000.0)
# ('Armenia', 'Visa not required', 12433089919.0)
# ('Australia', 'eVisa/Visa on arrival', 1432200000000.0)
# ('Austria', 'Visa not required', 455737000000.0)
# ('Azerbaijan', 'eVisa/Visa on arrival', 46939529412.0)
# ('Bahrain', 'eVisa/Visa on arrival', 37746196809.0)
# ('Bangladesh', 'eVisa/Visa on arrival', 274025000000.0)
# ('Belarus', 'Visa not required', 59662495092.0)
# ('Belgium', 'Visa not required', 531767000000.0)
# ('Belize', 'Visa not required', 1925000000.0)
# ('Benin', 'eVisa/Visa on arrival', 10358985583.0)
# ('Bhutan', 'Visa required', 2534965163.0)
# ('Bolivia', 'eVisa/Visa on arrival', 40287647757.0)
# ('Bosnia and Herzegovina', 'Visa not required', 19781776101.0)
# ('Botswana', 'Visa not required', 18616018903.0)
# ('Brazil', 'Visa not required', 1868630000000.0)
# ('Brunei', 'Visa not required', 13567099498.0)
# ('Bulgaria', 'Visa not required', 65132951116.0)
# ('Burkina Faso', 'eVisa/Visa on arrival', 14441763759.0)
# ('Burundi', 'Visa required', 3078029929.0)
# ('Cambodia', 'eVisa/Visa on arrival', 24571753583.0)
# ('Cameroon', 'Visa required', 38502059858.0)
# ('Canada', 'Visa not required', 1709330000000.0)
# ('Cape Verde', 'eVisa/Visa on arrival', 1986928612.0)
# ('Central African Republic', 'Visa not required', 2379716827.0)
# ('Chad', 'Visa required', 11302544205.0)
# ('Chile', 'Visa not required', 298231000000.0)
# ('China', 'Visa required', 13608200000000.0)
# ('Colombia', 'Visa not required', 330228000000.0)
# ('Comoros', 'eVisa/Visa on arrival', 1203080508.0)
# ('Democratic Republic of the Congo', 'Visa required', 47227535291.0)
# ('Republic of the Congo', 'Visa required', 11263682694.0)
# ('Costa Rica', 'Visa not required', 60126014829.0)
# ("Côte d'Ivoire", 'eVisa/Visa on arrival', 43007045466.0)
# ('Croatia', 'Visa not required', 60805659436.0)
# ('Cyprus', 'Visa not required', 24469841832.0)
# ('Czech Republic', 'Visa not required', 244105000000.0)
# ('Denmark', 'Visa not required', 351300000000.0)
# ('Djibouti', 'eVisa/Visa on arrival', 1965982322.0)
# ('Dominica', 'Visa not required', 503646211.1)
# ('Dominican Republic', 'Visa not required', 81298585403.0)
# ('Ecuador', 'Visa not required', 108398000000.0)
# ('Egypt', 'eVisa/Visa on arrival', 250895000000.0)
# ('El Salvador', 'Visa not required', 26056950000.0)
# ('Equatorial Guinea', 'Visa not required', 13317453070.0)
# ('Estonia', 'Visa not required', 30284890757.0)
# ('Eswatini', 'Visa not required', 4703787507.0)
# ('Ethiopia', 'eVisa/Visa on arrival', 84355462494.0)
# ('Fiji', 'Visa not required', 5479504926.0)
# ('Finland', 'Visa not required', 275683000000.0)
# ('France', 'Visa not required', 2777540000000.0)
# ('Gabon', 'eVisa/Visa on arrival', 17017401832.0)
# ('Gambia', 'Visa required', 1624464137.0)
# ('Georgia', 'Visa not required', 16209818081.0)
# ('Germany', 'Visa not required', 3996760000000.0)
# ('Ghana', 'Visa required', 65556464056.0)
# ('Greece', 'Visa not required', 218032000000.0)
# ('Grenada', 'Visa not required', 1207454556.0)
# ('Guatemala', 'Visa not required', 78460447920.0)
# ('Guinea', 'Visa required', 10989790256.0)
# ('Guinea-Bissau', 'eVisa/Visa on arrival', 1458156026.0)
# ('Guyana', 'Visa not required', 3610435299.0)
# ('Haiti', 'Visa not required', 9658084644.0)
# ('Honduras', 'Visa not required', 23803230473.0)
# ('Hungary', 'Visa not required', 155703000000.0)
# ('Iceland', 'Visa not required', 25878475760.0)
# ('India', 'eVisa/Visa on arrival', 2726320000000.0)
# ('Indonesia', 'Visa not required', 1042170000000.0)
# ('Iraq', 'Visa required', 225914000000.0)
# ('Ireland', 'Visa not required', 375903000000.0)
# ('Israel', 'Visa not required', 369690000000.0)
# ('Italy', 'Visa not required', 2073900000000.0)
# ('Jamaica', 'Visa not required', 15717858487.0)
# ('Japan', 'Visa not required', 4970920000000.0)
# ('Jordan', 'eVisa/Visa on arrival', 42290832158.0)
# ('Kazakhstan', 'Visa not required', 170539000000.0)
# ('Kenya', 'eVisa/Visa on arrival', 87908262520.0)
# ('Kiribati', 'Visa not required', 188284518.8)
# ('South Korea', 'Visa not required', 1619420000000.0)
# ('Kuwait', 'eVisa/Visa on arrival', 141678000000.0)
# ('Kyrgyzstan', 'Visa not required', 8092836609.0)
# ('Laos', 'eVisa/Visa on arrival', 18130724396.0)
# ('Latvia', 'Visa not required', 34849078086.0)
# ('Lebanon', 'eVisa/Visa on arrival', 56639155556.0)
# ('Lesotho', 'Visa not required', 2791762880.0)
# ('Liberia', 'Visa required', 3249000000.0)
# ('Libya', 'Visa required', 48319620013.0)
# ('Lithuania', 'Visa not required', 53251369047.0)
# ('Luxembourg', 'Visa not required', 69487922619.0)
# ('Madagascar', 'eVisa/Visa on arrival', 12100459087.0)
# ('Malawi', 'eVisa/Visa on arrival', 7064971176.0)
# ('Malaysia', 'Visa not required', 354348000000.0)
# ('Maldives', 'eVisa/Visa on arrival', 5272288443.0)
# ('Mali', 'Visa required', 17196688920.0)
# ('Malta', 'Visa not required', 14542039605.0)
# ('Marshall Islands', 'Visa not required', 211523642.4)
# ('Mauritania', 'eVisa/Visa on arrival', 5365868725.0)
# ('Mauritius', 'Visa not required', 14220348673.0)
# ('Mexico', 'Visa not required', 1223810000000.0)
# ('Micronesia', 'Visa not required', 344501760.0)
# ('Moldova', 'Visa not required', 11309082555.0)
# ('Mongolia', 'Visa not required', 13009574621.0)
# ('Montenegro', 'Visa not required', 5452173041.0)
# ('Morocco', 'Visa not required', 118495000000.0)
# ('Mozambique', 'eVisa/Visa on arrival', 14457964381.0)
# ('Myanmar', 'eVisa/Visa on arrival', 71214803378.0)
# ('Namibia', 'Visa not required', 14521711630.0)
# ('Nauru', 'Visa required', 114718022.8)
# ('Nepal', 'eVisa/Visa on arrival', 28812491892.0)
# ('Netherlands', 'Visa not required', 912872000000.0)
# ('New Zealand', 'Visa not required', 205025000000.0)
# ('Nicaragua', 'Visa not required', 13117859222.0)
# ('Niger', 'Visa required', 9239513530.0)
# ('Nigeria', 'Visa required', 397270000000.0)
# ('North Macedonia', 'Visa not required', 12672131053.0)
# ('Norway', 'Visa not required', 434751000000.0)
# ('Oman', 'eVisa/Visa on arrival', 79294928479.0)
# ('Pakistan', 'eVisa/Visa on arrival', 312570000000.0)
# ('Palau', 'Visa not required', 310111145.0)
# ('Panama', 'Visa not required', 65055100000.0)
# ('Papua New Guinea', 'eVisa/Visa on arrival', 23431596214.0)
# ('Paraguay', 'eVisa/Visa on arrival', 40842341774.0)
# ('Peru', 'Visa not required', 222238000000.0)
# ('Philippines', 'Visa not required', 330910000000.0)
# ('Poland', 'Visa not required', 585783000000.0)
# ('Portugal', 'Visa not required', 237979000000.0)
# ('Qatar', 'Visa not required', 192009000000.0)
# ('Romania', 'Visa not required', 239553000000.0)
# ('Russia', 'Visa required', 1657550000000.0)
# ('Rwanda', 'eVisa/Visa on arrival', 9509003197.0)
# ('Saint Kitts & Nevis', 'Visa not required', 1039875050.0)
# ('Saint Lucia', 'Visa not required', 1876189778.0)
# ('St. Vincent & Grenadines', 'Visa not required', 813093984.1)
# ('Samoa', 'eVisa/Visa on arrival', 861494700.7)
# ('Sao Tome & Principe', 'Visa not required', 422296762.3)
# ('Saudi Arabia', 'Visa required', 782483000000.0)
# ('Senegal', 'Visa not required', 24129599552.0)
# ('Serbia', 'Visa not required', 50508366850.0)
# ('Seychelles', 'eVisa/Visa on arrival', 1590180446.0)
# ('Sierra Leone', 'Visa required', 3999945202.0)
# ('Singapore', 'Visa not required', 364157000000.0)
# ('Slovakia', 'Visa not required', 106472000000.0)
# ('Slovenia', 'Visa not required', 54235484383.0)
# ('Solomon Islands', 'eVisa/Visa on arrival', 1411904531.0)
# ('Somalia', 'eVisa/Visa on arrival', 7484000000.0)
# ('South Africa', 'Visa not required', 366298000000.0)
# ('Spain', 'Visa not required', 1426190000000.0)
# ('Sri Lanka', 'eVisa/Visa on arrival', 88900770858.0)
# ('Sudan', 'Visa required', 40851536134.0)
# ('Suriname', 'eVisa/Visa on arrival', 3427269682.0)
# ('Sweden', 'Visa not required', 551032000000.0)
# ('Switzerland', 'Visa not required', 705501000000.0)
# ('Tajikistan', 'eVisa/Visa on arrival', 7522947810.0)
# ('Tanzania', 'eVisa/Visa on arrival', 57437073927.0)
# ('Thailand', 'Visa not required', 504993000000.0)
# ('Timor-Leste', 'eVisa/Visa on arrival', 2581000000.0)
# ('Togo', 'eVisa/Visa on arrival', 5300214337.0)
# ('Tonga', 'eVisa/Visa on arrival', 450353313.9)
# ('Trinidad and Tobago', 'Visa not required', 23410353435.0)
# ('Tunisia', 'Visa not required', 39860715814.0)
# ('Turkey', 'eVisa/Visa on arrival', 766509000000.0)
# ('Turkmenistan', 'Visa required', 40761142857.0)
# ('Tuvalu', 'eVisa/Visa on arrival', 42587778.47)
# ('Uganda', 'eVisa/Visa on arrival', 27476945526.0)
# ('Ukraine', 'Visa not required', 130832000000.0)
# ('United Arab Emirates', 'eVisa/Visa on arrival', 414179000000.0)
# ('United Kingdom', 'Visa not required', 2825210000000.0)
# ('Uruguay', 'Visa not required', 59596885024.0)
# ('Uzbekistan', 'eVisa/Visa on arrival', 50499920318.0)
# ('Vanuatu', 'Visa not required', 887817896.3)
# ('Vietnam', 'eVisa/Visa on arrival', 244948000000.0)
# ('Yemen', 'Visa required', 26914402224.0)
# ('Zambia', 'eVisa/Visa on arrival', 26720073436.0)
# ('Zimbabwe', 'eVisa/Visa on arrival', 31000519447.0)

# %% [markdown]
# ## 5.1 In your next vacation...
# 1. country w/o visa requiremnt
# 2. list of favourate cities
# 3. favourite dish in that country

# %%
sel = [Visa.country, City_list.cities, Yummy.dish, Population.population, GDP.gdp_2018,]
rows = session.query(*sel).filter(Visa.visa_requirement == "Visa not required",
                                  Visa.country == Population.country,
                                  Visa.country == City_list.country, 
                                  Visa.country == Yummy.country,
                                  Visa.country == GDP.country
                                 )

# %%
i = 1
for record in rows:
    print(i,". ",  record)
    i += 1
# Out:
# 1 .  ('Argentina', 'Buenos Aires', 'Asado', 45101781, 518475000000.0)
# 2 .  ('Austria', 'Vienna', 'Wiener schnitzel, Tafelspitz', 8766201, 455737000000.0)
# 3 .  ('Belgium', 'Brussels', 'Moules-frites', 11562784, 531767000000.0)
# 4 .  ('Brazil', 'Rio de Janeiro', 'Feijoada', 212392717, 1868630000000.0)
# 5 .  ('Brazil', 'Sao Paulo', 'Feijoada', 212392717, 1868630000000.0)
# 6 .  ('Bulgaria', 'Burgas', 'Banitsa, Bob chorba', 6988739, 65132951116.0)
# 7 .  ('Bulgaria', 'Sofia', 'Banitsa, Bob chorba', 6988739, 65132951116.0)
# 8 .  ('Canada', 'Toronto', 'Kraft Dinner', 37279811, 1709330000000.0)
# 9 .  ('Canada', 'Vancouver', 'Kraft Dinner', 37279811, 1709330000000.0)
# 10 .  ('Czech Republic', 'Prague', 'roast pork with dumplings and sauerkraut', 10630589, 244105000000.0)
# 11 .  ('Dominican Republic', 'Punta Cana', 'rice, red beans, and meat', 10996774, 81298585403.0)
# 12 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 13 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 14 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 15 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 16 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 17 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 18 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 19 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 20 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 21 .  ('France', 'Nice', None, 65480710, 2777540000000.0)
# 22 .  ('France', 'Nice', 'Cr�pe, Pot-au-feu,Macaron, Bisque', 65480710, 2777540000000.0)
# 23 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 24 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 25 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 26 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 27 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 28 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 29 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 30 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 31 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 32 .  ('France', 'Paris', None, 65480710, 2777540000000.0)
# 33 .  ('France', 'Paris', 'Cr�pe, Pot-au-feu,Macaron, Bisque', 65480710, 2777540000000.0)
# 34 .  ('Germany', 'Berlin', 'Currywurst, Sauerbraten, Bratwurst', 82438639, 3996760000000.0)
# 35 .  ('Germany', 'Frankfurt', 'Currywurst, Sauerbraten, Bratwurst', 82438639, 3996760000000.0)
# 36 .  ('Germany', 'Munich', 'Currywurst, Sauerbraten, Bratwurst', 82438639, 3996760000000.0)
# 37 .  ('Hungary', 'Budapest', 'Guly�s,', 9655361, 155703000000.0)
# 38 .  ('Indonesia', 'Denpasar', 'Tumpeng Sate,Soto,Nasi goreng', 269536482, 1042170000000.0)
# 39 .  ('Indonesia', 'Jakarta', 'Tumpeng Sate,Soto,Nasi goreng', 269536482, 1042170000000.0)
# 40 .  ('Ireland', 'Dublin', 'Colcannon,Irish stew ', 4847139, 375903000000.0)
# 41 .  ('Italy', 'Florence', 'Pasta,Polenta,Pizza, Risotto', 59216525, 2073900000000.0)
# 42 .  ('Italy', 'Milan', 'Pasta,Polenta,Pizza, Risotto', 59216525, 2073900000000.0)
# 43 .  ('Italy', 'Rome', 'Pasta,Polenta,Pizza, Risotto', 59216525, 2073900000000.0)
# 44 .  ('Italy', 'Venice', 'Pasta,Polenta,Pizza, Risotto', 59216525, 2073900000000.0)
# 45 .  ('Japan', 'Tokyo', 'Sushi, Japanese curry,Ramen ', 126854745, 4970920000000.0)
# 46 .  ('South Korea', 'Seoul', 'Kimchi, bulgogi', 51339238, 1619420000000.0)
# 47 .  ('Malaysia', 'Kuala Lumpur', 'Nasi lemak,Satay, Laksa, Roti canai', 32454455, 354348000000.0)
# 48 .  ('Mexico', 'Cancun', 'Tacos, Mole poblano,Chiles en nogada', 132328035, 1223810000000.0)
# 49 .  ('Mexico', 'Mexico City', 'Tacos, Mole poblano,Chiles en nogada', 132328035, 1223810000000.0)
# 50 .  ('Morocco', 'Marrakech', 'Couscous, Tagine', 36635156, 118495000000.0)
# 51 .  ('Netherlands', 'Amsterdam', None, 17132908, 912872000000.0)
# 52 .  ('Netherlands', 'Amsterdam', 'Keshi yena', 17132908, 912872000000.0)
# 53 .  ('Netherlands', 'Amsterdam', 'Stamppot, hutspot', 17132908, 912872000000.0)
# 54 .  ('New Zealand', 'Auckland', None, 4792409, 205025000000.0)
# 55 .  ('New Zealand', 'Auckland', None, 4792409, 205025000000.0)
# 56 .  ('New Zealand', 'Auckland', None, 4792409, 205025000000.0)
# 57 .  ('New Zealand', 'Auckland', None, 4792409, 205025000000.0)
# 58 .  ('New Zealand', 'Auckland', 'Bacon and egg pie, lamb, pavlova', 4792409, 205025000000.0)
# 59 .  ('New Zealand', 'Christchurch', None, 4792409, 205025000000.0)
# 60 .  ('New Zealand', 'Christchurch', None, 4792409, 205025000000.0)
# 61 .  ('New Zealand', 'Christchurch', None, 4792409, 205025000000.0)
# 62 .  ('New Zealand', 'Christchurch', None, 4792409, 205025000000.0)
# 63 .  ('New Zealand', 'Christchurch', 'Bacon and egg pie, lamb, pavlova', 4792409, 205025000000.0)
# 64 .  ('Peru', 'Lima', 'Ceviche', 32933835, 222238000000.0)
# 65 .  ('Philippines', 'Manila', 'Adobo,Lechon (both unofficial)', 108106310, 330910000000.0)
# 66 .  ('Poland', 'Warsaw', 'Bigos, Pierogi,Kotlet schabowy, ?urek', 38028278, 585783000000.0)
# 67 .  ('Portugal', 'Lisbon', 'Bacalhau', 10254666, 237979000000.0)
# 68 .  ('Qatar', 'Doha', None, 2743901, 192009000000.0)
# 69 .  ('Romania', 'Bucharest', 'M?m?lig?, Sarmale, Mici', 19483360, 239553000000.0)
# 70 .  ('Singapore', 'Singapore', 'Chilli crab,Hainanese Chicken Rice', 5868104, 364157000000.0)
# 71 .  ('South Africa', 'Johannesburg', 'Bobotie', 58065097, 366298000000.0)
# 72 .  ('Spain', 'Barcelona', 'Tortilla espa�ola ', 46441049, 1426190000000.0)
# 73 .  ('Spain', 'Madrid', 'Tortilla espa�ola ', 46441049, 1426190000000.0)
# 74 .  ('Thailand', 'Bangkok', 'Pad Thai, Tom Yum Goong', 69306160, 504993000000.0)
# 75 .  ('Thailand', 'Chiang Mai', 'Pad Thai, Tom Yum Goong', 69306160, 504993000000.0)
# 76 .  ('Thailand', 'Pattaya', 'Pad Thai, Tom Yum Goong', 69306160, 504993000000.0)
# 77 .  ('Thailand', 'Phuket', 'Pad Thai, Tom Yum Goong', 69306160, 504993000000.0)
# 78 .  ('Tunisia', 'Djerba', 'Couscous, Kabkabou', 11783168, 39860715814.0)
# 79 .  ('Tunisia', 'Sousse', 'Couscous, Kabkabou', 11783168, 39860715814.0)
# 80 .  ('Ukraine', 'Kiev', 'Borscht, Varenyky ', 43795220, 130832000000.0)
# 81 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 82 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 83 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 84 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 85 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 86 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 87 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 88 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 89 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 90 .  ('United Kingdom', 'London', None, 66959016, 2825210000000.0)
# 91 .  ('United Kingdom', 'London', 'Beef,(especially roast beef/corned beef),Pudding ', 66959016, 2825210000000.0)
# 92 .  ('United Kingdom', 'London', 'Bermuda fish chowder', 66959016, 2825210000000.0)
# 93 .  ('United Kingdom', 'London', 'Cawl', 66959016, 2825210000000.0)
# 94 .  ('United Kingdom', 'London', 'Fish and chips,Chicken tikka masala (Indian-British curry)', 66959016, 2825210000000.0)
# 95 .  ('United Kingdom', 'London', 'Haggis', 66959016, 2825210000000.0)
# 96 .  ('United Kingdom', 'London', 'Ulster fry', 66959016, 2825210000000.0)
